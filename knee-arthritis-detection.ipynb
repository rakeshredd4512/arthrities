# %% [markdown]
# ![](https://www.moati.com.au/wp-content/uploads/2022/05/knee-arthritis-surgery.jpg)

# %% [markdown]
# # Initial Imports

# %%
import tensorflow
import numpy as np
import keras
import cv2,os

# %% [markdown]
# # Data Preprocessing

# %%
data_path='C:/Users/krake/Downloads/arthrities/archive/Training'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels)) #empty dictionary
print(label_dict)
print(categories)
print(labels)
# Out:
# {'0Normal': 0, '1Doubtful': 1, '2Mild': 2, '3Moderate': 3, '4Severe': 4}
# ['0Normal', '1Doubtful', '2Mild', '3Moderate', '4Severe']
# [0, 1, 2, 3, 4]

# %%
img_size=256
data=[]
label=[]

for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the image  into 256 x 256, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            label.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)
        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %% [markdown]
# # Rescale and assign  catagorical labels

# %%
data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
label=np.array(label)

from keras.utils import to_categorical
new_label= to_categorical(label)

# %%
new_label.shape
# Out:
# (1650, 5)

# %%
data.shape
# Out:
# (1650, 256, 256, 1)

# %%
data.shape[1:]
# Out:
# (256, 256, 1)

# %% [markdown]
# # Model Creation

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(128,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The thrid convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
#Flatten layer to stack the output convolutions from 3rd convolution layer
model.add(Dropout(0.2))

model.add(Dense(128,activation='relu'))
#Dense layer of 128 neurons

model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
#Dense layer of 64 neurons

model.add(Dense(5,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# C:\Users\krake\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 128)       │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 254, 254, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 64)        │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 125, 125, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 60, 60, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 28800)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 28800)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,686,528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 5)                   │             325 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,788,645 (14.45 MB)
#  Trainable params: 3,788,645 (14.45 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Splitting data into traning and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,new_label,test_size=0.1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.squeeze(x_test[i]))
    plt.xlabel(categories[np.argmax(y_test[i])])
plt.show()

# %% [markdown]
# # Model Training

# %%
history=model.fit(x_train,y_train,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.3164 - loss: 1.5448 - val_accuracy: 0.3300 - val_loss: 1.5049
# Epoch 2/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.3273 - loss: 1.5194 - val_accuracy: 0.3535 - val_loss: 1.4962
# Epoch 3/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.3190 - loss: 1.4997 - val_accuracy: 0.3636 - val_loss: 1.4468
# Epoch 4/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.3497 - loss: 1.4391 - val_accuracy: 0.3569 - val_loss: 1.4416
# Epoch 5/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.3659 - loss: 1.4578 - val_accuracy: 0.4108 - val_loss: 1.3891
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.3679 - loss: 1.4090 - val_accuracy: 0.3906 - val_loss: 1.4093
# Epoch 7/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.3671 - loss: 1.4214 - val_accuracy: 0.4343 - val_loss: 1.3737
# Epoch 8/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.3755 - loss: 1.3624 - val_accuracy: 0.4815 - val_loss: 1.3140
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.4300 - loss: 1.2923 - val_accuracy: 0.5051 - val_loss: 1.2784
# Epoch 10/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.4921 - loss: 1.3240 - val_accuracy: 0.4377 - val_loss: 1.3386
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.3994 - loss: 1.3576 - val_accuracy: 0.4815 - val_loss: 1.2694
# Epoch 12/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.4722 - loss: 1.2699 - val_accuracy: 0.4512 - val_loss: 1.2612
# Epoch 13/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.4543 - loss: 1.2839 - val_accuracy: 0.5320 - val_loss: 1.1804
# Epoch 14/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.4997 - loss: 1.2110 - val_accuracy: 0.4983 - val_loss: 1.1553
# Epoch 15/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.5181 - loss: 1.1496 - val_accuracy: 0.5455 - val_loss: 1.1219
# Epoch 16/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.5490 - loss: 1.1076 - val_accuracy: 0.5017 - val_loss: 1.1811
# Epoch 17/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 344s 9s/step - accuracy: 0.5515 - loss: 1.0937 - val_accuracy: 0.5084 - val_loss: 1.1496
# Epoch 18/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.5932 - loss: 1.0289 - val_accuracy: 0.5421 - val_loss: 1.1174
# Epoch 19/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.6224 - loss: 0.9748 - val_accuracy: 0.5455 - val_loss: 1.1241
# Epoch 20/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.5986 - loss: 0.9779 - val_accuracy: 0.5960 - val_loss: 1.1321
# Epoch 21/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.6350 - loss: 0.9407 - val_accuracy: 0.5657 - val_loss: 1.1033
# Epoch 22/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.5764 - loss: 0.9784 - val_accuracy: 0.5589 - val_loss: 1.1393
# Epoch 23/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.6442 - loss: 0.8793 - val_accuracy: 0.5387 - val_loss: 1.2167
# Epoch 24/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.6613 - loss: 0.8302 - val_accuracy: 0.5657 - val_loss: 1.1847
# Epoch 25/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.6692 - loss: 0.7759 - val_accuracy: 0.5387 - val_loss: 1.2495
# Epoch 26/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 119s 3s/step - accuracy: 0.6969 - loss: 0.7420 - val_accuracy: 0.5455 - val_loss: 1.2774
# Epoch 27/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.7436 - loss: 0.6579 - val_accuracy: 0.5488 - val_loss: 1.3282
# Epoch 28/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.7381 - loss: 0.6668 - val_accuracy: 0.5791 - val_loss: 1.2949
# Epoch 29/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 173s 5s/step - accuracy: 0.7528 - loss: 0.5899 - val_accuracy: 0.5387 - val_loss: 1.4135
# Epoch 30/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.7847 - loss: 0.5318 - val_accuracy: 0.5320 - val_loss: 1.3632
# Epoch 31/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.8190 - loss: 0.4711 - val_accuracy: 0.5623 - val_loss: 1.5409
# Epoch 32/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8026 - loss: 0.4834 - val_accuracy: 0.5455 - val_loss: 1.5154
# Epoch 33/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.8295 - loss: 0.4323 - val_accuracy: 0.5354 - val_loss: 1.6580
# Epoch 34/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.8330 - loss: 0.4138 - val_accuracy: 0.5488 - val_loss: 1.6776
# Epoch 35/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8532 - loss: 0.3719 - val_accuracy: 0.5589 - val_loss: 1.6069
# Epoch 36/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8538 - loss: 0.3571 - val_accuracy: 0.5320 - val_loss: 1.7900
# Epoch 37/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9001 - loss: 0.2688 - val_accuracy: 0.5758 - val_loss: 1.6649
# Epoch 38/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9113 - loss: 0.2357 - val_accuracy: 0.5522 - val_loss: 1.8139
# Epoch 39/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.9181 - loss: 0.2278 - val_accuracy: 0.5522 - val_loss: 1.9169
# Epoch 40/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.9338 - loss: 0.1830 - val_accuracy: 0.5286 - val_loss: 1.9448
# Epoch 41/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9276 - loss: 0.1934 - val_accuracy: 0.5589 - val_loss: 1.8656
# Epoch 42/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9438 - loss: 0.1707 - val_accuracy: 0.5556 - val_loss: 2.1146
# Epoch 43/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.8860 - loss: 0.3011 - val_accuracy: 0.5522 - val_loss: 1.9697
# Epoch 44/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9472 - loss: 0.1698 - val_accuracy: 0.5522 - val_loss: 2.0114
# Epoch 45/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.9489 - loss: 0.1395 - val_accuracy: 0.5825 - val_loss: 2.1442
# Epoch 46/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9476 - loss: 0.1727 - val_accuracy: 0.5589 - val_loss: 2.0766
# Epoch 47/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.9689 - loss: 0.0983 - val_accuracy: 0.5724 - val_loss: 2.2020
# Epoch 48/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9551 - loss: 0.1253 - val_accuracy: 0.5455 - val_loss: 2.1075
# Epoch 49/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9773 - loss: 0.0760 - val_accuracy: 0.5354 - val_loss: 2.2989
# Epoch 50/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9585 - loss: 0.1124 - val_accuracy: 0.5589 - val_loss: 2.1809
# Epoch 51/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9816 - loss: 0.0709 - val_accuracy: 0.5556 - val_loss: 2.3733
# Epoch 52/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9471 - loss: 0.1642 - val_accuracy: 0.5690 - val_loss: 2.2223
# Epoch 53/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9647 - loss: 0.1139 - val_accuracy: 0.5488 - val_loss: 2.3493
# Epoch 54/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9647 - loss: 0.0960 - val_accuracy: 0.5623 - val_loss: 2.1916
# Epoch 55/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9845 - loss: 0.0625 - val_accuracy: 0.5556 - val_loss: 2.5422
# Epoch 56/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9923 - loss: 0.0362 - val_accuracy: 0.5825 - val_loss: 2.4790
# Epoch 57/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9697 - loss: 0.0751 - val_accuracy: 0.5724 - val_loss: 2.2054
# Epoch 58/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9767 - loss: 0.0723 - val_accuracy: 0.5522 - val_loss: 2.3460
# Epoch 59/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9698 - loss: 0.0686 - val_accuracy: 0.5455 - val_loss: 2.5605
# Epoch 60/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9758 - loss: 0.0786 - val_accuracy: 0.5421 - val_loss: 2.4485
# Epoch 61/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9796 - loss: 0.0665 - val_accuracy: 0.5859 - val_loss: 2.5644
# Epoch 62/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9822 - loss: 0.0707 - val_accuracy: 0.5488 - val_loss: 2.5484
# Epoch 63/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9752 - loss: 0.0716 - val_accuracy: 0.5623 - val_loss: 2.3150
# Epoch 64/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9855 - loss: 0.0459 - val_accuracy: 0.5825 - val_loss: 2.5955
# Epoch 65/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.9679 - loss: 0.0837 - val_accuracy: 0.5758 - val_loss: 2.7251
# Epoch 66/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9807 - loss: 0.0657 - val_accuracy: 0.5455 - val_loss: 2.4920
# Epoch 67/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.9709 - loss: 0.0722 - val_accuracy: 0.5758 - val_loss: 2.5074
# Epoch 68/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9559 - loss: 0.1075 - val_accuracy: 0.5589 - val_loss: 2.3285
# Epoch 69/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.9785 - loss: 0.0819 - val_accuracy: 0.5455 - val_loss: 2.4917
# Epoch 70/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9722 - loss: 0.0826 - val_accuracy: 0.5522 - val_loss: 2.6042
# Epoch 71/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.9863 - loss: 0.0510 - val_accuracy: 0.5589 - val_loss: 2.5556
# Epoch 72/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.9832 - loss: 0.0560 - val_accuracy: 0.5488 - val_loss: 2.4946
# Epoch 73/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9936 - loss: 0.0288 - val_accuracy: 0.5589 - val_loss: 2.4536
# Epoch 74/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9828 - loss: 0.0547 - val_accuracy: 0.5690 - val_loss: 2.5596
# Epoch 75/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9804 - loss: 0.0433 - val_accuracy: 0.5556 - val_loss: 2.4962
# Epoch 76/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.9860 - loss: 0.0339 - val_accuracy: 0.5522 - val_loss: 2.6413
# Epoch 77/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9871 - loss: 0.0505 - val_accuracy: 0.5791 - val_loss: 2.4997
# Epoch 78/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9861 - loss: 0.0375 - val_accuracy: 0.5690 - val_loss: 2.4882
# Epoch 79/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9839 - loss: 0.0393 - val_accuracy: 0.5657 - val_loss: 2.6644
# Epoch 80/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9954 - loss: 0.0220 - val_accuracy: 0.5724 - val_loss: 2.6496
# Epoch 81/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9935 - loss: 0.0268 - val_accuracy: 0.5859 - val_loss: 2.6175
# Epoch 82/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9812 - loss: 0.0453 - val_accuracy: 0.5657 - val_loss: 2.9939
# Epoch 83/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9859 - loss: 0.0321 - val_accuracy: 0.5522 - val_loss: 2.9507
# Epoch 84/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9882 - loss: 0.0313 - val_accuracy: 0.5926 - val_loss: 2.6429
# Epoch 85/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9924 - loss: 0.0217 - val_accuracy: 0.5758 - val_loss: 2.7149
# Epoch 86/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9940 - loss: 0.0175 - val_accuracy: 0.5926 - val_loss: 2.9343
# Epoch 87/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9915 - loss: 0.0297 - val_accuracy: 0.5758 - val_loss: 2.6678
# Epoch 88/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9851 - loss: 0.0562 - val_accuracy: 0.5690 - val_loss: 2.9269
# Epoch 89/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9840 - loss: 0.0415 - val_accuracy: 0.5758 - val_loss: 2.8499
# Epoch 90/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9810 - loss: 0.0438 - val_accuracy: 0.5724 - val_loss: 2.8016
# Epoch 91/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9624 - loss: 0.1011 - val_accuracy: 0.5657 - val_loss: 2.7462
# Epoch 92/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9866 - loss: 0.0393 - val_accuracy: 0.5690 - val_loss: 2.6404
# Epoch 93/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9924 - loss: 0.0296 - val_accuracy: 0.5522 - val_loss: 2.5741
# Epoch 94/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9745 - loss: 0.0763 - val_accuracy: 0.5522 - val_loss: 2.4328
# Epoch 95/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9830 - loss: 0.0591 - val_accuracy: 0.5387 - val_loss: 2.7849
# Epoch 96/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.9874 - loss: 0.0328 - val_accuracy: 0.5791 - val_loss: 2.6547
# Epoch 97/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.9901 - loss: 0.0258 - val_accuracy: 0.5825 - val_loss: 2.7221
# Epoch 98/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.9893 - loss: 0.0283 - val_accuracy: 0.5455 - val_loss: 2.7678
# Epoch 99/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.9916 - loss: 0.0246 - val_accuracy: 0.5556 - val_loss: 3.0179
# Epoch 100/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.9934 - loss: 0.0239 - val_accuracy: 0.5825 - val_loss: 3.0632

# %% [markdown]
# # Export The Model

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Plot The Training Loss And Accuracy

# %%
from matplotlib import pyplot as plt

# %%
N = 100 #number of epochs

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("CNN_Model")

# %% [markdown]
# # Accuracy

# %%
vaL_loss, val_accuracy= model.evaluate(x_test, y_test, verbose=0)
print("test loss:", vaL_loss,'%')
print("test accuracy:", val_accuracy,"%")
# Out:
# test loss: 3.5129427909851074 %
# test accuracy: 0.5454545617103577 %

# %% [markdown]
# # Prediction

# %%
X = 32

img_size = 256

img_single = x_test[X]
img_single = cv2.resize(img_single, (img_size, img_size))
img_single = (np.expand_dims(img_single, 0))
img_single = img_single.reshape(img_single.shape[0],256,256,1)

predictions_single = model.predict(img_single)
print('A.I predicts:',categories[np.argmax(predictions_single)])
print("Correct prediction for label",np.argmax(y_test[X]),'is',categories[np.argmax(y_test[X])])
plt.imshow(np.squeeze(img_single))
plt.grid(False)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# A.I predicts: 1Doubtful
# Correct prediction for label 1 is 1Doubtful

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

test_labels = np.argmax(y_test, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=-1)


cm  = confusion_matrix(test_labels, predictions)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True,cmap=plt.cm.Blues)
plt.xticks(range(5), ['Normal','Doubtful','Mid','Moderate','Severe'], fontsize=16)
plt.yticks(range(5), ['Normal','Doubtful','Mid','Moderate','Severe'], fontsize=16)
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step

# %%
#!!pip install mlxtend

# %%
vaL_loss, val_accuracy= model.evaluate(x_train, y_train, verbose=0)
print("train loss:", vaL_loss,'%')
print("train accuracy:", val_accuracy,"%")
# Out:
# train loss: 0.6169352531433105 %
# train accuracy: 0.9144781231880188 %
